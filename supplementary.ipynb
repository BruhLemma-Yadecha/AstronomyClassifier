# %% [markdown]
# # Supplementary Comparisons
# This extra notebook inherits the setup from the primary notebook and benchmarks the problem using some extra models.

# %%
# %run preprocessing_lean.ipynb
# %run visuals.ipynb

# %%
'''
Model C: k-Nearest Neighbours
'''

N_NEIGHBOURS = 10

from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(
    n_neighbors=N_NEIGHBOURS,
    weights='distance',
    p=2,
    metric='minkowski',
    n_jobs=-1
)

knn_model.fit(X_trn, y_trn)
generate_statistics(knn_model.predict)
# Out:
#       Dataset  Accuracy
# 0    Training  1.000000
# 1  Validation  0.962712
# 2        Test  0.963120

# %%
'''
Model D: Gaussian Naive Bayes
'''

from sklearn.naive_bayes import GaussianNB

gnb_model = GaussianNB()

gnb_model.fit(X_trn, y_trn)
generate_statistics(gnb_model.predict)
# Out:
#       Dataset  Accuracy
# 0    Training  0.924671
# 1  Validation  0.928234
# 2        Test  0.927772
